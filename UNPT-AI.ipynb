# %%
# %pip install openai==0.28
# Out:
# Collecting openai==0.28
#   Downloading openai-0.28.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: requests>=2.20 in c:\users\ghdi1\anaconda3\lib\site-packages (from openai==0.28) (2.31.0)
# Requirement already satisfied: tqdm in c:\users\ghdi1\anaconda3\lib\site-packages (from openai==0.28) (4.65.0)
# Requirement already satisfied: aiohttp in c:\users\ghdi1\anaconda3\lib\site-packages (from openai==0.28) (3.9.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ghdi1\anaconda3\lib\site-packages (from requests>=2.20->openai==0.28) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ghdi1\anaconda3\lib\site-packages (from requests>=2.20->openai==0.28) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ghdi1\anaconda3\lib\site-packages (from requests>=2.20->openai==0.28) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ghdi1\anaconda3\lib\site-packages (from requests>=2.20->openai==0.28) (2024.2.2)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\ghdi1\anaconda3\lib\site-packages (from aiohttp->openai==0.28) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\ghdi1\anaconda3\lib\site-packages (from aiohttp->openai==0.28) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\ghdi1\anaconda3\lib\site-packages (from aiohttp->openai==0.28) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\ghdi1\anaconda3\lib\site-packages (from aiohttp->openai==0.28) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\ghdi1\anaconda3\lib\site-packages (from aiohttp->openai==0.28) (1.9.3)
# Requirement already satisfied: colorama in c:\users\ghdi1\anaconda3\lib\site-packages (from tqdm->openai==0.28) (0.4.6)
# Downloading openai-0.28.0-py3-none-any.whl (76 kB)
#    ---------------------------------------- 0.0/76.5 kB ? eta -:--:--
#    ----- ---------------------------------- 10.2/76.5 kB ? eta -:--:--
#    ----- ---------------------------------- 10.2/76.5 kB ? eta -:--:--
#    ----- ---------------------------------- 10.2/76.5 kB ? eta -:--:--
#    ----- ---------------------------------- 10.2/76.5 kB ? eta -:--:--
#    ------------------------------------- -- 71.7/76.5 kB 357.2 kB/s eta 0:00:01
#    ---------------------------------------- 76.5/76.5 kB 352.7 kB/s eta 0:00:00
# Installing collected packages: openai
# Successfully installed openai-0.28.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import openai

openai.api_key  = ""

# %%
model = "gpt-4o"

userName = "최시훈"
userAge = 21
userGender = "남성"
userMajor = "ERICA 공학대학 스마트융합공학부 스마트ICT융합전공"
userHobby = "코딩"
userCountry = "japan, korea, china"

userProfile = f"{userName}은(는) {userAge}살이고, {userGender}이며, {userMajor}을(를) 전공하고 있습니다. {userHobby}을(를) 좋아하며, {userCountry}에 있는 대학을 찾고 있습니다."
messages = [
    {
        "role": "system",
        "content": (
            "University Classification Prompt:\n\n"
            "Based on the provided university data, provide leisure, weather, location, and major information for the city where each university is located. Follow these criteria to classify each category:\n\n"
            "Leisure activities:\n\n"
            "- Classify as 'Extroverted (E)' if the city mainly features active facilities such as amusement parks, landmarks, cafes, bars, sports stadiums, etc.\n"
            "- Classify as 'Introverted (I)' if the city mainly features calm facilities such as libraries, cinemas, bookstores, etc.\n\n"
            "Weather:\n\n"
            "- Classify as 'Sunny (S)' if the city generally has warm weather with temperatures frequently above 15°C.\n"
            "- Classify as 'Freeze (F)' if the city generally has cold weather with temperatures frequently below 15°C.\n\n"
            "Location:\n\n"
            "- Classify as 'City (C)' if the city's population exceeds 100,000.\n"
            "- Classify as 'Town (T)' if the city's population is 100,000 or less.\n\n"
            "Major:\n\n"
            "- Classify as 'Liberal arts (L)' if the university is known for liberal arts, humanities, or business.\n"
            "- Classify as 'Nature (N)' if the university is known for science, technology, engineering, or mathematics.\n\n"
            "Ensure each university is classified with exactly one option for each category (E/I, S/F, C/T, L/N).\n\n"
            "Response format:\n\n"
            "대학: [University Name]\n"
            "UNPT: [E | I][S | F][C | T][L | N]\n"
            "여가정보: [Extroverted | Introverted]\n"
            "지리정보: [Sunny | Freeze]\n"
            "지역정보: [City | Town]\n"
            "전공정보: [Liberal arts | Nature]\n"
            "도시: [City Name]\n"
            "추천 시설: [Recommended Facility 1], [Recommended Facility 2], [Recommended Facility 3]\n\n"
            "Initial Question Generation:\n\n"
            "Based on the provided criteria, generate an initial open-ended question in Korean to classify the user's preferences. \n"
            "It doesn't give you any options to choose from.\n"
            "question is very creativity and diversity. Continue asking up to three open-ended questions based on the user's responses. After receiving the responses, classify the UNPT and recommend three universities that match the determined UNPT.\n"
            "Please return only questions\n\n"
            "End of prompt."
        )
    },
    {
        "role": "user",
        "content": f"이 유저의 프로필 데이터와 유사한 대학을 추천해주면 돼 {userProfile}"
    }
]

response = openai.ChatCompletion.create(
    model= model,
    messages=messages,
    temperature=1,
    max_tokens=1000,
    top_p=1,
    frequency_penalty=0,
    presence_penalty=0
)

print(response.choices[0].message['content'])
# Out:
# 1. 최시훈님, 여가 활동에서 어떤 스타일을 더 좋아하시나요? 커피숍과 바 같은 활기찬 곳을 선호하시나요, 아니면 도서관과 영화관 같은 조용한 곳을 선호하시나요?
#
# 2. 최시훈님이 선호하시는 날씨는 어떤가요? 따뜻한 기후를 더 좋아하시나요, 아니면 추운 날씨를 더 좋아하시나요?
#
# 3. 최시훈님, 도시의 크기에 대한 선호도가 있나요? 큰 도시에 있는 대학교를 선호하시나요, 아니면 작은 도시나 타운에 있는 대학교를 선호하시나요?

# %%
model = "gpt-4o"

userName = "최시훈"
userAge = 21
userGender = "남성"
userMajor = "공학대학 스마트융합공학부 스마트ICT융합전공"
userHobby = "코딩"
userCountry = "USA"
userResponse1 = "나는 집에서 jpop을 들으면서 코딩하는것을 좋아해"
userResponse2 = "둘다 싫어"
userResponse3 = "Anyway"

userProfile = f"{userName}은(는) {userAge}살이고, {userGender}이며, {userMajor}을(를) 전공하고 있습니다. {userHobby}을(를) 좋아하며, {userCountry}에 있는 대학을 찾고 있습니다."
userResponse = f"{userResponse1}, {userResponse2}, {userResponse3}"
messages = [
    {
        "role": "system",
        "content": (
            "University Classification Prompt:\n\n"
            "Based on the provided university data, provide leisure, weather, location, and major information for the city where each university is located. Follow these criteria to classify each category:\n\n"
            "Leisure activities:\n\n"
            "- Classify as 'Extroverted (E)' if the city mainly features active facilities such as amusement parks, landmarks, cafes, bars, sports stadiums, etc.\n"
            "- Classify as 'Introverted (I)' if the city mainly features calm facilities such as libraries, cinemas, bookstores, etc.\n\n"
            "Weather:\n\n"
            "- Classify as 'Sunny (S)' if the city generally has warm weather with temperatures frequently above 15°C.\n"
            "- Classify as 'Freeze (F)' if the city generally has cold weather with temperatures frequently below 15°C.\n\n"
            "Location:\n\n"
            "- Classify as 'City (C)' if the city's population exceeds 100,000.\n"
            "- Classify as 'Town (T)' if the city's population is 100,000 or less.\n\n"
            "Major:\n\n"
            "- Classify as 'Liberal arts (L)' if the university is known for liberal arts, humanities, or business.\n"
            "- Classify as 'Nature (N)' if the university is known for science, technology, engineering, or mathematics.\n\n"

            "Ensure each university is classified with exactly one option for each category (E/I, S/F, C/T, L/N). The final classification for each university should follow this format: ESCL, ESCN, ESTL, ESTN, EFCL, EFCN, EFTL, EFTN, ISCL, ISCN, ISTL, ISTN, IFCL, IFCN, IFTL, IFTN, according to the criteria above.\n\n"

            "Must Only Return Response format"
            
            "Response format:\n\n"
            "대학: [University Name]\n"
            "UNPT: [E | I][S | F][C | T][L | N]\n"
            "여가정보: [Extroverted | Introverted]\n"
            "지리정보: [Sunny | Freeze]\n"
            "지역정보: [City | Town]\n"
            "전공정보: [Liberal arts | Nature]\n"
            "기숙사 여부: [True | False]\n"
            "학기제: [2학기 | 4학기 | 그외]\n"
            "도시: [City Name]\n"
            "추천 음식: [Recommended restaurant 1], [Recommended restaurant 2], [Recommended restaurant 3]\n"
            "추천 시설: [Recommended Facility 1], [Recommended Facility 2], [Recommended Facility 3]\n"
            "추천 맛집: [Recommended restaurant 1], [Recommended restaurant 2], [Recommended restaurant 3]\n\n"
            
            "End of prompt."
        )
    },
    {
        "role": "user",
        "content": f"이 유저의 프로필 데이터와 같은 UNPT를 가진 유사한 대학을 추천해주면 돼 {userProfile}, {userResponse}"
    }
]

response = openai.ChatCompletion.create(
    model= model,
    messages=messages,
    temperature=1,
    max_tokens=1000,
    top_p=1,
    frequency_penalty=0,
    presence_penalty=0
)

print(response.choices[0].message['content'])
# Out:
# 대학: Massachusetts Institute of Technology (MIT)
# UNPT: ESCN
# 여가정보: Extroverted
# 지리정보: Freeze
# 지역정보: City
# 전공정보: Nature
# 기숙사 여부: True
# 학기제: 2학기
# 도시: Cambridge, MA
# 추천 음식: Craigie on Main, Flour Bakery & Cafe, Clover Food Lab
# 추천 시설: Harvard Art Museums, MIT Museum, Charles River Esplanade
# 추천 맛집: Craigie on Main, Flour Bakery & Cafe, Clover Food Lab
#
# 대학: Stanford University
# UNPT: EFCN
# 여가정보: Extroverted
# 지리정보: Freeze
# 지역정보: City
# 전공정보: Nature
# 기숙사 여부: True
# 학기제: 4학기
# 도시: Stanford, CA
# 추천 음식: The Treehouse, Coupa Cafe, Ike's Place
# 추천 시설: Stanford University Museum of Art, Rodin Sculpture Garden, Stanford Theatre
# 추천 맛집: The Treehouse, Coupa Cafe, Ike's Place
#
# 대학: California Institute of Technology (Caltech)
# UNPT: ESCN
# 여가정보: Extroverted
# 지리정보: Sunny
# 지역정보: City
# 전공정보: Nature
# 기숙사 여부: True
# 학기제: 4학기
# 도시: Pasadena, CA
# 추천 음식: The Royce, Pasadena Sandwich Company, Union Restaurant
# 추천 시설: The Huntington Library, Art Museum, and Botanical Gardens, Pasadena Playhouse, Descanso Gardens
# 추천 맛집: The Royce, Pasadena Sandwich Company, Union Restaurant
