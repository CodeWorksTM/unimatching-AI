# %%
# %pip install openai==0.28
# Out:
# Requirement already satisfied: openai==0.28 in /opt/anaconda3/lib/python3.11/site-packages (0.28.0)
# Requirement already satisfied: requests>=2.20 in /opt/anaconda3/lib/python3.11/site-packages (from openai==0.28) (2.31.0)
# Requirement already satisfied: tqdm in /opt/anaconda3/lib/python3.11/site-packages (from openai==0.28) (4.66.1)
# Requirement already satisfied: aiohttp in /opt/anaconda3/lib/python3.11/site-packages (from openai==0.28) (3.9.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.11/site-packages (from requests>=2.20->openai==0.28) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.11/site-packages (from requests>=2.20->openai==0.28) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.11/site-packages (from requests>=2.20->openai==0.28) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.11/site-packages (from requests>=2.20->openai==0.28) (2024.2.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/anaconda3/lib/python3.11/site-packages (from aiohttp->openai==0.28) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in /opt/anaconda3/lib/python3.11/site-packages (from aiohttp->openai==0.28) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/anaconda3/lib/python3.11/site-packages (from aiohttp->openai==0.28) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/anaconda3/lib/python3.11/site-packages (from aiohttp->openai==0.28) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/anaconda3/lib/python3.11/site-packages (from aiohttp->openai==0.28) (1.9.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
import openai

openai.api_key  = ""

# %%
model = "gpt-4o"

# Korean
# userName = "이정호"
# userGender = "남성"
# userMajor = "공학계열"
# userHobby = "코딩"
# userCountry = "japan, korea, china"

# English
userName = "Jay"
userGender = "Male"
userMajor = "Engineering"
userHobby = "coding"
userCountry = "japan, korea, china"
userLang = "English"
    

# userProfile = f"{userName}은(는) {userGender}이며, {userMajor}을(를) 전공하고 있습니다. {userHobby}을(를) 좋아하며, {userCountry}에 있는 대학을 찾고 있습니다."
userProfile = f"{userName} is {userGender} and is majoring in {userMajor}. {userName} likes {userHobby} and is looking for a university in {userCountry}. You have to respond in {userLang}."
messages = [
    {
        "role": "system",
        "content": (
            "University Classification Prompt:\n\n"
            "Based on the provided university data, provide leisure, weather, location, and major information for the city where each university is located. Follow these criteria to classify each category:\n\n"
            "Leisure activities:\n\n"
            "- Classify as 'Extroverted (E)' if the city mainly features active facilities such as amusement parks, landmarks, cafes, bars, sports stadiums, etc.\n"
            "- Classify as 'Introverted (I)' if the city mainly features calm facilities such as libraries, cinemas, bookstores, etc.\n\n"
            "Weather:\n\n"
            "- Classify as 'Sunny (S)' if the city generally has warm weather with temperatures frequently above 15°C.\n"
            "- Classify as 'Freeze (F)' if the city generally has cold weather with temperatures frequently below 15°C.\n\n"
            "Location:\n\n"
            "- Classify as 'City (C)' if the city's population exceeds 100,000.\n"
            "- Classify as 'Town (T)' if the city's population is 100,000 or less.\n\n"
            "Major:\n\n"
            "- Classify as 'Liberal arts (L)' if the university is known for liberal arts, humanities, or business.\n"
            "- Classify as 'Nature (N)' if the university is known for science, technology, engineering, or mathematics.\n\n"
            "Ensure each university is classified with exactly one option for each category (E/I, S/F, C/T, L/N).\n\n"
            "대학: [University Name]\n"
            "UNPT: [E | I][S | F][C | T][L | N]\n"
            "여가정보: [Extroverted | Introverted]\n"
            "지리정보: [Sunny | Freeze]\n"
            "지역정보: [City | Town]\n"
            "전공정보: [Liberal arts | Nature]\n"
            "도시: [City Name]\n"
            "추천 시설: [Recommended Facility 1], [Recommended Facility 2], [Recommended Facility 3]\n\n"
            "Response format:\n\n"
            "1. [first question]"
            "2. [second question]"
            "3. [third question]"
            "Initial Question Generation:\n\n"
            "Based on the provided criteria, generate an initial open-ended question in Korean to classify the user's preferences. \n"
            "It doesn't give you any options to choose from.\n"
            "question is very creativity and diversity. Continue asking up to three open-ended questions based on the user's responses. After receiving the responses, classify the UNPT and recommend three universities that match the determined UNPT.\n"
            "Please return only questions\n\n"
        )
    },
    {
        "role": "user",
        "content": f"To gather information to recommend universities similar to this user's profile, I must ask 3 questions. Please respond in the user's input language. {userProfile}"
    }
]

response = openai.ChatCompletion.create(
    model= model,
    messages=messages,
    temperature=1,
    max_tokens=1000,
    top_p=1,
    frequency_penalty=0,
    presence_penalty=0
)

print(response.choices[0].message['content'])
# Out:
# 1. What kind of city environment do you prefer to live in: a bustling metropolis with lots of activities or a quieter town with peaceful surroundings?
#
# 2. Do you prefer a warm climate with lots of sunshine or a colder climate with chillier temperatures and occasional snow?
#
# 3. Are you more interested in outdoor social activities like sports and festivals, or do you enjoy indoor activities like reading and watching movies?
#
# Please provide your responses to these questions.

# %%
model = "gpt-4o"

# 우리가 가지고 있는 대학 리스트에서 우선으로 추천하기 완료

univList = ["서울대학교, 연세대학교, 고려대학교, 한양대학교 ERICA, 안산대학교, 서강대학교, 동국대학교, 순천향대학교, 가천대학교, 전주대학교, 한국교통대학교, 공주대학교"]
# Korean
# userName = "이정호"
# userGender = "남성"
# userMajor = "공학계열"
# userHobby = "코딩, 축구, 술"
# userCountry = "Korea"
# userDormitory = "true"
# userResponse1 = "나는 친구들과 술마시면서 축구보는 걸 좋아해, 그리고 집에서 개발하는 것도 좋아해"
# userResponse2 = "따뜻하고 햇빛이 좋은 날씨가 좋아."
# userResponse3 = "인구가 많은 대도시가 좋지!!"
# userLang = "Korean"

# English
userName = "Jay"
userGender = "Male"
userMajor = "Engineering"
userHobby = "coding"
userCountry = "japan, korea, china"
userDormitory = "true"
userResponse1 = "I like drinking with friends while watching soccer, and I also enjoy developing at home."
userResponse2 = "I like warm and sunny weather."
userResponse3 = "I prefer big cities with large populations"
userLang = "English"

userProfile = f"{userName} is {userGender} and is majoring in {userMajor}. {userName} likes {userHobby} and is looking for a university in {userCountry} that {userDormitory} has dormitories. You have to respond in {userLang}."
userResponse = f"{userResponse1}, {userResponse2}, {userResponse3}"
messages = [
    {
        "role": "system",
        "content": (
            "University Classification Prompt:\n\n"
            "Based on the provided university data, provide leisure, weather, location, and major information for the city where each university is located. Follow these criteria to classify each category:\n\n"
            "Leisure activities:\n\n"
            "- Classify as 'Extroverted (E)' if the city mainly features active facilities such as amusement parks, landmarks, cafes, bars, sports stadiums, etc.\n"
            "- Classify as 'Introverted (I)' if the city mainly features calm facilities such as libraries, cinemas, bookstores, etc.\n\n"
            "Weather:\n\n"
            "- Classify as 'Sunny (S)' if the city generally has warm weather with temperatures frequently above 15°C.\n"
            "- Classify as 'Freeze (F)' if the city generally has cold weather with temperatures frequently below 15°C.\n\n"
            "Location:\n\n"
            "- Classify as 'City (C)' if the city's population exceeds 100,000.\n"
            "- Classify as 'Town (T)' if the city's population is 100,000 or less.\n\n"
            "Major:\n\n"
            "- Classify as 'Liberal arts (L)' if the university is known for liberal arts, humanities, or business.\n"
            "- Classify as 'Nature (N)' if the university is known for science, technology, engineering, or mathematics.\n\n"

            "Ensure each university is classified with exactly one option for each category (E/I, S/F, C/T, L/N). The final classification for each university should follow this format: ESCL, ESCN, ESTL, ESTN, EFCL, EFCN, EFTL, EFTN, ISCL, ISCN, ISTL, ISTN, IFCL, IFCN, IFTL, IFTN, according to the criteria above.\n\n"

            "Must Only Return Response format"
            
            "Response format:\n\n"
            "UNPT: [E | I][S | F][C | T][L | N]\n"
            "여가정보: [Extroverted | Introverted]\n"
            "지리정보: [Sunny | Freeze]\n"
            "지역정보: [City | Town]\n"
            "전공정보: [Liberal arts | Nature]\n"
        )
    },
    {
        "role": "user",
        "content": f"Please generate UNPT using this user's profile data and response. Follow the above format strictly and provide the output in plain text without using Markdown. {userProfile}, {userResponse}"
    }
]

response = openai.ChatCompletion.create(
    model= model,
    messages=messages,
    temperature=1,
    max_tokens=1000,
    top_p=1,
    frequency_penalty=0,
    presence_penalty=0
)

print(response.choices[0].message['content'])
# Out:
# UNPT: ESCN
# Leisure information: Extroverted
# Weather information: Sunny
# Location information: City
# Major information: Nature

# %%
model = "gpt-4o"

# 우리가 가지고 있는 대학 리스트에서 우선으로 추천하기 완료

univList = ["서울대학교, 연세대학교, 고려대학교, 한양대학교 ERICA, 도쿄대학교 안산대학교, 서강대학교, 동국대학교, 순천향대학교, 가천대학교, 전주대학교, 한국교통대학교, 공주대학교"]

# Korean
# userName = "이정호"
# userGender = "남성"
# userMajor = "공학계열"
# userHobby = "코딩, 축구, 술"
# userUNPT = "ESCN"
# userCountry = "Korea"
# userDormitory = "true"
# userResponse1 = "나는 친구들과 술마시면서 축구보는 걸 좋아해, 그리고 집에서 개발하는 것도 좋아해"
# userResponse2 = "따뜻하고 햇빛이 좋은 날씨가 좋아."
# userResponse3 = "인구가 많은 대도시가 좋지!!"
# userLang = "Korean"

# English
userName = "Jay"
userGender = "Male"
userMajor = "Engineering"
userHobby = "coding"
userUNPT = "ESCN"
userCountry = "japan, korea, china"
userDormitory = "true"
userResponse1 = "I like drinking with friends while watching soccer, and I also enjoy developing at home."
userResponse2 = "I like warm and sunny weather."
userResponse3 = "I prefer big cities with large populations"
userLang = "English"


userProfile = f"{userName} is {userGender}, {userLang} with a UNPT of {userUNPT}, and is majoring in {userMajor}. {userName} likes {userHobby} and is looking for a university in {userCountry} with {userDormitory} dormitory availability among {univList}."
userResponse = f"{userResponse1}, {userResponse2}, {userResponse3}"
messages = [
    {
        "role": "system",
        "content": (
            "University Classification Prompt:\n\n"
            "Based on the provided university data, provide leisure, weather, location, and major information for the city where each university is located. Follow these criteria to classify each category:\n\n"
            "Leisure activities:\n\n"
            "- Classify as 'Extroverted (E)' if the city mainly features active facilities such as amusement parks, landmarks, cafes, bars, sports stadiums, etc.\n"
            "- Classify as 'Introverted (I)' if the city mainly features calm facilities such as libraries, cinemas, bookstores, etc.\n\n"
            "Weather:\n\n"
            "- Classify as 'Sunny (S)' if the city generally has warm weather with temperatures frequently above 15°C.\n"
            "- Classify as 'Freeze (F)' if the city generally has cold weather with temperatures frequently below 15°C.\n\n"
            "Location:\n\n"
            "- Classify as 'City (C)' if the city's population exceeds 100,000.\n"
            "- Classify as 'Town (T)' if the city's population is 100,000 or less.\n\n"
            "Major:\n\n"
            "- Classify as 'Liberal arts (L)' if the university is known for liberal arts, humanities, or business.\n"
            "- Classify as 'Nature (N)' if the university is known for science, technology, engineering, or mathematics.\n\n"
            
            "Ensure each university is classified with exactly one option for each category (E/I, S/F, C/T, L/N). The final classification for each university should follow this format: ESCL, ESCN, ESTL, ESTN, EFCL, EFCN, EFTL, EFTN, ISCL, ISCN, ISTL, ISTN, IFCL, IFCN, IFTL, IFTN, according to the criteria above.\n\n"
            
            "Must Only Return Response format"
            
            "Response format:\n\n"
            "대학: [University Name]\n"
            "UNPT: [E | I][S | F][C | T][L | N]\n"
            "여가정보: [Extroverted | Introverted]\n"
            "지리정보: [Sunny | Freeze]\n"
            "지역정보: [City | Town]\n"
            "전공정보: [Liberal arts | Nature]\n"
            "기숙사 여부: [True | False]\n"
            "학기제: [2 | 4 | Others]\n"
            "도시: [City Name]\n"
            "추천 음식: [Recommended food 1], [Recommended food 2], [Recommended food 3]\n"
            "추천 시설: [Recommended Facility 1], [Recommended Facility 2], [Recommended Facility 3]\n"
            "추천 맛집: [Recommended restaurant 1], [Recommended restaurant 2], [Recommended restaurant 3]\n\n"
            "Note: The response language must match userLang. If userLang is 'Korean', respond in Korean. If userLang is 'English', respond in English."
        )
    },
    {
        "role": "user",
        "content": f"Please recommend exactly 5 universities similar to this user's profile data with the same UNPT. The most appropriate university should be at the top, and you must strictly follow the above format. Additionally, recommend food, restaurants, and facilities. Provide the output in plain text without using Markdown. Use only universities from the provided list.\n\n{userProfile}\n\n{userResponse}\n\n{univList}\n\nNote: The response language must match userLang. If userLang is 'Korean', respond in Korean. If userLang is 'English', respond in English. If userLang is 'Japanese', respond in Japanese."
    }
]

response = openai.ChatCompletion.create(
    model="gpt-4o",
    messages=messages,
    temperature=1,
    max_tokens=1000,
    top_p=1,
    frequency_penalty=0,
    presence_penalty=0
)

print(response.choices[0].message['content'])
# Out:
# University: Tokyo University (University of Tokyo)
# UNPT: ESCN
# Leisure Info: Extroverted
# Weather Info: Sunny
# Location Info: City
# Major Info: Nature
# Dormitory Availability: True
# Semester System: 2
# City: Tokyo
# Recommended Food: Sushi, Ramen, Tempura
# Recommended Facilities: Tokyo Tower, Meiji Shrine, Shibuya Crossing
# Recommended Restaurants: Sukiyabashi Jiro, Ichiran Ramen, Sushi Dai
#
# University: Seoul National University
# UNPT: ESCN
# Leisure Info: Extroverted
# Weather Info: Sunny
# Location Info: City
# Major Info: Nature
# Dormitory Availability: True
# Semester System: 2
# City: Seoul
# Recommended Food: Kimchi, Bibimbap, Bulgogi
# Recommended Facilities: N Seoul Tower, Gyeongbokgung Palace, Dongdaemun Design Plaza
# Recommended Restaurants: Tosokchon Samgyetang, Myeongdong Kyoja, Jin Ok-Hwa Original Hwalpan
#
# University: Yonsei University
# UNPT: ESCN
# Leisure Info: Extroverted
# Weather Info: Sunny
# Location Info: City
# Major Info: Nature
# Dormitory Availability: True
# Semester System: 2
# City: Seoul
# Recommended Food: Samgyeopsal, Hotteok, Tteokbokki
# Recommended Facilities: Han River Park, Hongdae, Itaewon
# Recommended Restaurants: Jungsik, Maple Tree House, Hanwoori
#
# University: Korea University
# UNPT: ESCN
# Leisure Info: Extroverted
# Weather Info: Sunny
# Location Info: City
# Major Info: Nature
# Dormitory Availability: True
# Semester System: 2
# City: Seoul
# Recommended Food: Kimchi Jjigae, Dak Galbi, Naengmyeon
# Recommended Facilities: Bukchon Hanok Village, Cheonggyecheon Stream, Insadong
# Recommended Restaurants: Anju Maeul, Tosokchon, Baekjeong BBQ
#
# University: Hanyang University ERICA
# UNPT: ESCN
# Leisure Info: Extroverted
# Weather Info: Sunny
# Location Info: City
# Major Info: Nature
# Dormitory Availability: True
# Semester System: 2
# City: Ansan
# Recommended Food: Haemul Pajeon, Soondubu Jjigae, Japchae
# Recommended Facilities: Daebu Island, Ansan Reed Marsh Park, Gwanggyosan Mountain
# Recommended Restaurants: Jangsu Galbi, Kkot Dwaeji, Choryang Restaurant

# %%
# UNPT - University Classification Prompt:

model = "gpt-4o"

universityName = {"한양대학교 ERICA, 서울대학교, 충남대학교, 공주대학교"}
messages = [
    {
        "role": "system",
        "content": (
            "University Classification Prompt:\n\n"
            "Based on the provided university data, provide leisure, weather, location, and major information for the city where each university is located. Follow these criteria to classify each category:\n\n"
            "Leisure activities:\n\n"
            "- Classify as 'Extroverted (E)' if the city mainly features active facilities such as amusement parks, landmarks, cafes, bars, sports stadiums, etc.\n"
            "- Classify as 'Introverted (I)' if the city mainly features calm facilities such as libraries, cinemas, bookstores, etc.\n\n"
            "Weather:\n\n"
            "- Classify as 'Sunny (S)' if the city generally has warm weather with temperatures frequently above 15°C.\n"
            "- Classify as 'Freeze (F)' if the city generally has cold weather with temperatures frequently below 15°C.\n\n"
            "Location:\n\n"
            "- Classify as 'City (C)' if the city's population exceeds 100,000.\n"
            "- Classify as 'Town (T)' if the city's population is 100,000 or less.\n\n"
            "Major:\n\n"
            "- Classify as 'Liberal arts (L)' if the university is known for liberal arts, humanities, or business.\n"
            "- Classify as 'Nature (N)' if the university is known for science, technology, engineering, or mathematics.\n\n"

            "Ensure each university is classified with exactly one option for each category (E/I, S/F, C/T, L/N). The final classification for each university should follow this format: ESCL, ESCN, ESTL, ESTN, EFCL, EFCN, EFTL, EFTN, ISCL, ISCN, ISTL, ISTN, IFCL, IFCN, IFTL, IFTN, according to the criteria above.\n\n"

            "Must Only Return Response format"
            
            "Response format: "
            "대학: [University Name] \n"
            "UNPT: [E | I][S | F][C | T][L | N]"
            
        )
    },
    {
        "role": "user",
        "content": f" You need to print the UNPT of {universityName} and must follow the format above. "
    }
]

response = openai.ChatCompletion.create(
    model= model,
    messages=messages,
    temperature=1,
    max_tokens=1000,
    top_p=1,
    frequency_penalty=0,
    presence_penalty=0
)

print(response.choices[0].message['content'])
# Out:
# 대학: 한양대학교 ERICA
# UNPT: ESTN
#
# 대학: 서울대학교
# UNPT: ESCL
#
# 대학: 충남대학교
# UNPT: EFCL
#
# 대학: 공주대학교
# UNPT: IFCL
